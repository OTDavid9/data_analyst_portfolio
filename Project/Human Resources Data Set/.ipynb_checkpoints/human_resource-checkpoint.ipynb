# %% [markdown]
# <div style="background-color:#ECF2FF;
#             padding: 3%;">
#
# <h1 style="text-align:center;
#                    font-size: 2.5em;
#                    text-transform: uppercase;
#                    color: navy;"> Engineer T and Sons Limited </h1>
#
# <hr>
#
# <img  style="width:100%" src="engineer_t.jpg" alt="Engineer T and Sons Limited" />
#
# <p style="text-align:right;
#                    font-size: 1.2em;
#                   font-weight:bold;
#                   color: navy;"><em>Presented By:</em> Obidokun Tunji D. </p>
#
# <p style="text-align:right;
#                    font-size: 1.2em;
#                    font-weight:bold;
#                    color: navy;"><em>Date:</em> 25/02/2023 </p>
#
# <p style="text-align:center;
#                    font-size: 1.0em;
#                    color: navy;">&copy 2023 | Engineer T and Sons Limited | Data Analytics Report  </p>
#          <hr>
#
# </div>

# %% [markdown]
# <h1 style="text-align:left;
#            font-size: 1.5em;
#            text-transform: uppercase;
#            color: navy;"> ANALYSIS REPORT </h1>
#
# <!--  <p style="text-align:center;
#            font-size: 1.0em;
#            color: navy;">&copy 2023 | Engineer T and Sons Limited | Data Analytics Report  </p> -->

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display ##### Display Dataframe as Table #######
import imageio.v2 as imageio

print("Setup complete!")
# Out:
# Setup complete!

# %%
#### Reading the dataset ########

df = pd.read_csv("HRDataset.csv")

df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# #### List of Columns in the datasets and information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %% [markdown]
# #### Checking for missing values and handling them

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %% [markdown]
# <h3>There are 207 missing data points for the column "Date of Termination" and 8 for "ManagerID" </h3>
# <h3>Therefore, we handle these missing values by replacing them with "Not available" </h3>

# %%
df.fillna("Not Availabe ", inplace = True)
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# #### Checking if there still missing values

# %%
df.isnull().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# ...

# %% [markdown]
# #### All missing values in the dataframe have successfully handled .

# %% [markdown]
# # Analysis Report

# %% [markdown]
# ## Introduction
#
# To enhance employee performance, it is necessary to comprehend the factors that influence it. In Nigeria, Engineer T and Sons Ltd is a rapidly expanding business that offers services beyond help with research and phone support engineering, content creation, and copywriting. The business wants to learn more about the behaviors of its workers as performance indicators.

# %% [markdown]
# ## Objectives
#
# This analysis report is guide with the following questions:
#
# * Is there any relationship between who a person works for and their performance score?
# * What is the overall diversity profile of the organization?
# * What are our best recruiting sources if we want to ensure a diverse organization?
# * What is the correlation between employees' performance and salary?
# * Can we predict who is going to terminate and who isn't? What level of accuracy can we achieve on this?
# * Are there areas of the company where pay is not equitable?

# %% [markdown]
# #### Data Exploration

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# ## Question 1: Is there any relationship between who a person works for and their performance score?

# %%
performance =  df.PerfScoreID.tolist()
performance


x  = df.groupby('ManagerName').PerfScoreID.mean().round(2).sort_values(ascending = False) 

y= x.index.tolist()

managers_employees_perf = pd.DataFrame(list(zip(y,x)))

managers_employees_perf.columns = [ "Managers", "Average Employees Performance",]

managers_employees_perf
# Out:
#               Managers  Average Employees Performance
# 0         Eric Dougall                           3.25
# 1      Jennifer Zamora                           3.14
# 2           Simon Roup                           3.12
# 3      Alex Sweetwater                           3.11
# 4           Janet King                           3.11
# 5        Kelley Spirea                           3.09
# 6        Ketsia Liebig                           3.05
# 7     Brian Champaigne                           3.00
# 8        David Stanley                           3.00
# 9         Elijiah Gray                           3.00
# 10  Brandon R. LeBlanc                           3.00
# 11       Lynn Daneault                           3.00
# 12  Board of Directors                           3.00
# 13      Webster Butler                           3.00
# 14      Kissy Sullivan                           2.95
# 15            Amy Dunn                           2.90
# ...

# %%
plt.figure(figsize=(15,7))
plt.scatter(y, x, marker = "s", color = "red", label= x, lw=2, )
plt.plot(y, x, ls= "--", color = "blue", )
plt.axhline(y = 2.99, color = 'green', linestyle = '-', label="Average Performance {2.99}")
plt.title("AVERAGE EMPLOYEES' PERFORMANCE UNDER VARIOUS MANAGERS", fontsize= 18, color = "navy", pad=2)
plt.xlabel("Best Performing Managers", fontsize= 15, color = "navy")
plt.ylabel("Average Permance of Employees", fontsize= 15, color = "navy")
plt.xticks(rotation = 90, color = "navy")
plt.yticks(rotation = 0, color = "r")
plt.legend(loc=1, fontsize = 11)
plt.grid()
plt.axis([-1,28, 2.6, 3.28])
plt.show()
plt.savefig("Perf.pdf")

# %% [markdown]
# #### From the graph above, it can be deduced that employees who are supervised and managed by various by administrators have significant different level of performances. Most of the employees performed above the average level of 2.99 under fourteen managers while other performed below average under seven managers.
#
# #### For, instance, workers under the supervision of Eric Dougall has the highest level of job performance with 3.25 average performance. However, employees under Debra Houlihan has the lowest level of performance of 2.67.

# %% [markdown]
# ## Question 2. What is the overall diversity profile of the organization?

# %%
x= df.FromDiversityJobFairID.value_counts().tolist()
y= df.FromDiversityJobFairID.value_counts().index.tolist()

diversity_profile =  pd.DataFrame(list(zip(y,x)))
diversity_profile.columns = ["Options", "Frequency"]

for i in diversity_profile["Options"]:
    if i == 0:
        diversity_profile["Options"][i] = False
    else:
        diversity_profile["Options"][i] = True
        
diversity_profile
# Out:
#   Options  Frequency
# 0   False        282
# 1    True         29

# %%
# Pie Chaart showing the overall diversity profile of the organisation 
plt.figure(figsize=(16,5))
diversity_profile.Options


x = diversity_profile.Options
y = diversity_profile.Frequency

c = [ "#144272", "#205295" ,"#2C74B3"]
plt.pie(y,labels = x,autopct='%1.1f%%')
plt.title("Overall Diversity Profile of the Organisation")
plt.xlabel("Diversity Job Fairs ")
plt.ylabel("")
plt.xticks(rotation = 0, color = "Navy")
plt.yticks(rotation = 0, color = "Navy")
plt.axis('on') # We can have "on", "off" or "equal"
plt.legend()
plt.grid()
plt.show()
plt.savefig("Sources_of_recruitment.jpg", dpi = 75)

# %% [markdown]
# #### The Pie Chart above show that 90.7% of the employees do no believe that the organisation embraces opportunity that identifies individuals with unique background. However, 9.3% of the employees believe in diversity job fairs of the organisation.

# %% [markdown]
# ## Question 3. What are our best recruiting sources if we want to ensure a diverse organization?

# %%
Recruit_s = df.RecruitmentSource.value_counts()
Recruit_s.unique().tolist()

x = Recruit_s.index.tolist()
y = Recruit_s.unique().tolist()

Sources_of_Recruitment = pd.DataFrame(list(zip(x,y)))
Sources_of_Recruitment.columns = ["Sources of Recruitment", "Frequency"]
Sources_of_Recruitment
# Out:
#     Sources of Recruitment  Frequency
# 0                   Indeed         87
# 1                 LinkedIn         76
# 2            Google Search         49
# 3        Employee Referral         31
# 4       Diversity Job Fair         29
# 5            CareerBuilder         23
# 6                  Website         13
# 7                    Other          2
# 8  On-line Web application          1

# %%
Recruit_s = df.RecruitmentSource.value_counts()
Recruit_s.unique().tolist()

plt.figure(figsize=(16,12))

x = Recruit_s.index.tolist()
y = Recruit_s.unique().tolist()
c = ["#0A2647", "#144272", "#205295" ,"#2C74B3", "#2A1078","#3795BD","#3F58CD", "#4E31AA"]
plt.bar(x, y, width= .5, color = c, alpha = True, label = x)
plt.plot(x, y, alpha = True, c = "r")
plt.plot(80)
plt.title("BEST SOURCES OF RECRUITMENT FOR A DIVERSE ORGANISATION")
plt.xlabel("Sources of Recruitment")
plt.ylabel("Frequency")
plt.xticks(rotation = 75, color = "Navy")
plt.yticks(rotation = 0, color = "Navy")
plt.legend()
plt.grid()
# plt.show()
plt.savefig("Sources_of_recruitment.jpg", dpi = 75)
plt.savefig('./SVG.png')

# %% [markdown]
# ####  The bar chart above shows that the most of the recruitment sources are from indeed, LinkedIn and Google Search, which form the top three. Therefore, Indeed, LinkedIn and Google Search are the three best sources of recruitment among other sources.

# %% [markdown]
# ## Question 4: What is the correlation between employees' performance and salary?

# %%
df.columns

salary = x = df.Salary 
Performance = y = df.PerfScoreID 


# create correlation matrix
matrix = np.corrcoef(x, y)
 
x = matrix[0]
y = matrix[1]
# print matrix
correlation_table = pd.DataFrame(list(zip(x,y)))
correlation_table.columns = correlation_table.index = ["Salary", "Performance"]
correlation_table
# Out:
#                Salary  Performance
# Salary       1.000000     0.130903
# Performance  0.130903     1.000000

# %%
plt.figure(figsize=(16,9)) 
# plt.plot(x,y)
plt.scatter(salary, performance)
plt.grid()
plt.title("CORRELATION BETWEEN EMPLOYEES' SALARY AND PERFORMANCE", fontsize = 20)
# plt.axis([0.1309,1, 0, 1])
# Out:
# Text(0.5, 1.0, "CORRELATION BETWEEN EMPLOYEES' SALARY AND PERFORMANCE")

# %% [markdown]
# ## Question 5: Can we predict who is going to terminate and who isn't? What level of accuracy can we achieve on this?

# %% [markdown]
# ## Question 6: Are there areas of the company where pay is not equitable?
